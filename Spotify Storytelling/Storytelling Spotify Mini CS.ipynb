# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spot=pd.read_csv('Data/Spotify-2000.csv')
spot.head(4)
# Out:
#    Index           Title        Artist            Top Genre  Year  \
# 0      1         Sunrise   Norah Jones      adult standards  2004
# 1      2     Black Night   Deep Purple           album rock  2000
# 2      3  Clint Eastwood      Gorillaz  alternative hip hop  2001
# 3      4   The Pretender  Foo Fighters    alternative metal  2007
#
#    Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 0                     157      30            53            -14        11
# 1                     135      79            50            -11        17
# 2                     168      69            66             -9         7
# 3                     173      96            43             -4         3
#
#    Valence Length (Duration)  Acousticness  Speechiness  Popularity
# 0       68               201            94            3          71
# 1       81               207            17            7          39
# ...

# %% [markdown]
# Questions to be answered in this Spotify Dataset?
#
# - What is the corelation of song popularity to the amount of energy and the BPM?
# - From above, what song is played the most?

# %%
spot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1994 non-null   object
#  2   Artist                  1994 non-null   object
#  3   Top Genre               1994 non-null   object
#  4   Year                    1994 non-null   int64
#  5   Beats Per Minute (BPM)  1994 non-null   int64
#  6   Energy                  1994 non-null   int64
#  7   Danceability            1994 non-null   int64
#  8   Loudness (dB)           1994 non-null   int64
#  9   Liveness                1994 non-null   int64
#  10  Valence                 1994 non-null   int64
#  11  Length (Duration)       1994 non-null   object
#  12  Acousticness            1994 non-null   int64
#  13  Speechiness             1994 non-null   int64
# ...

# %%
spot.plot.scatter(x='Popularity', y='Beats Per Minute (BPM)', color ='turquoise')
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Beats Per Minute (BPM)'>

# %%
spot.plot.scatter(x='Popularity', y='Energy', color='blue')
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Energy'>

# %%
spot.plot.scatter(x='Popularity', y='Liveness')
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Liveness'>

# %% [markdown]
# So far we can see that the illistrations represent that the popularity feature is focuses on the higher 70-80s of the data (70-80 meaning there is greater popularity for a spesific track). From this we can infer that a thrid of the tracks in the dataset lay in this range. As per the coorelation of each the compared features against populartity, the energy, Liveness, and BPM fetures deomonstrate positive results; As the energy and BPM are in the higher ranges as well.

# %%
spot.plot.scatter(x='Danceability', y='Index', color = 'green')
# Out:
# <AxesSubplot:xlabel='Danceability', ylabel='Index'>

# %%
spot.plot.scatter(x='Danceability', y='Year')
# Out:
# <AxesSubplot:xlabel='Danceability', ylabel='Year'>

# %%
spot['Year']
# Out:
# 0       2004
# 1       2000
# 2       2001
# 3       2007
# 4       2002
#         ...
# 1989    1958
# 1990    1958
# 1991    1959
# 1992    1959
# 1993    1959
# Name: Year, Length: 1994, dtype: int64

# %%
spot['Top Genre'].describe()
# Out:
# count           1994
# unique           149
# top       album rock
# freq             413
# Name: Top Genre, dtype: object

# %%
spot['Title']
# Out:
# 0                      Sunrise
# 1                  Black Night
# 2               Clint Eastwood
# 3                The Pretender
# 4       Waitin' On A Sunny Day
#                  ...
# 1989          Heartbreak Hotel
# 1990                 Hound Dog
# 1991           Johnny B. Goode
# 1992                 Take Five
# 1993            Blueberry Hill
# Name: Title, Length: 1994, dtype: object

# %% [markdown]
# In terms of the danceability feature, we see that the the spread of the feature across the year and index has shown us that they are pretty similar. Over the number of song titles, the most populated area in the graph are shown to have high dancaeability in the year of 2010 and after. When bringing this to today's time. This seems to be accurate, due to the fact that older pop songs which one can dance to, such as Sweet Caroline, have high BPM, liveness, and energy.
